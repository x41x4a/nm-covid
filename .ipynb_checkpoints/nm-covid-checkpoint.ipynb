# %%
# Libraries

import matplotlib.pyplot as plt
import matplotlib.figure as figure
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# Data

df = pd.read_csv('covid.csv',parse_dates=['date'],index_col=['date'])
df.sort_values(by=['date'], inplace=True, ascending=True)
df.dropna(axis=0, how='all', inplace=True)
df.fillna('0 new cases',inplace=True)
df.head(10)
# Out:
#                             McKinleyCountyM  \
# date
# 2020-03-27   2 new cases in McKinley County
# 2020-03-28                      0 new cases
# 2020-03-29   4 new cases in McKinley County
# 2020-03-30   3 new cases in McKinley County
# 2020-03-31   4 new cases in McKinley County
# 2020-04-01   4 new cases in McKinley County
# 2020-04-02   4 new cases in McKinley County
# 2020-04-03   8 new cases in McKinley County
# 2020-04-04                      0 new cases
# 2020-04-05   9 new cases in McKinley County
#
#                              BernalilloCountyM BernalilloCountyS  \
# date
# 2020-03-27   27 new cases in Bernalillo County       0 new cases
# 2020-03-28   11 new cases in Bernalillo County       0 new cases
# 2020-03-29    9 new cases in Bernalillo County       0 new cases
# 2020-03-30   16 new cases in Bernalillo County       0 new cases
# 2020-03-31   12 new cases in Bernalillo County       0 new cases
# 2020-04-01   19 new cases in Bernalillo County       0 new cases
# 2020-04-02   15 new cases in Bernalillo County       0 new cases
# 2020-04-03   39 new cases in Bernalillo County       0 new cases
# 2020-04-04   23 new cases in Bernalillo County       0 new cases
# 2020-04-05   21 new cases in Bernalillo County       0 new cases
#
#                           McKinleyCountyS
# date
# 2020-03-27                    0 new cases
# 2020-03-28                    0 new cases
# 2020-03-29                    0 new cases
# 2020-03-30                    0 new cases
# 2020-03-31                    0 new cases
# 2020-04-01                    0 new cases
# 2020-04-02                    0 new cases
# 2020-04-03                    0 new cases
# 2020-04-04  1 new case in McKinley County
# 2020-04-05                    0 new cases

# %%
counties = ['Bernalillo','McKinley']

for county in counties:
    countyM = county + 'CountyM'
    countyS = county + 'CountyS'
    df[countyM] = df[countyM].astype(str)
    df[countyS] = df[countyS].astype(str)
    df[countyM] = df[countyM].str.extract(r'(\d+)', expand=False).astype(int)
    df[countyS] = df[countyS].str.extract(r'(\d+)', expand=False).astype(int)
    county_sum = df[countyM] + df[countyS]
    #print(county_sum)
    df[county] = county_sum
    
    df = df.drop(countyM, 1)
    df = df.drop(countyS, 1)
    
    df[county] = df[county].rolling(window=7).mean().round(decimals=0)
    #print(df[county])

df.fillna(0, inplace=True)
df
    
# grab dates with multiple new cases (M) and single new cases (S)
# convert to strings to strip out all but numbers, total up cases in new column
#df['BernalilloM'] = df['BernalilloCountyM'].astype(str)
#df['BernalilloS'] = df['BernalilloCountyS'].astype(str)
#df['BernalilloM'] = df['BernalilloM'].str.extract(r'(\d+)', expand=False).astype(int)
#df['BernalilloS'] = df['BernalilloS'].str.extract(r'(\d+)', expand=False).astype(int)
#bern_sum = df['BernalilloM'] + df['BernalilloS']
#df['Bernalillo'] = bern_sum

#df['McKinleyM'] = df['McKinleyCountyM'].astype(str)
#df['McKinleyS'] = df['McKinleyCountyS'].astype(str)
#df['McKinleyM'] = df['McKinleyCountyM'].str.extract(r'(\d+)', expand=False).astype(int)
#df['McKinleyS'] = df['McKinleyCountyS'].str.extract(r'(\d+)', expand=False).astype(int)
#mckinley_sum = df['McKinleyM'] + df['McKinleyS']
#df['McKinley'] = mckinley_sum

# drop unused columns
#df = df.drop('BernalilloCountyM',1)
#df = df.drop('BernalilloCountyS',1)
#df = df.drop('BernalilloM',1)
#df = df.drop('BernalilloS',1)

#df = df.drop('McKinleyCountyM',1)
#df = df.drop('McKinleyCountyS',1)
#df = df.drop('McKinleyM',1)
#df = df.drop('McKinleyS',1)

# calculate rolling 7-day average
#df['Bernalillo'] = df['Bernalillo'].rolling(window=7).mean()
#df['Bernalillo'] = df['Bernalillo'].rolling(window=7).mean()

#df.fillna(0)

# TODO
# 1 - Do the above for all other NM counties
# 2 - Calculate rolling 7-day average and graph that vs. daily new cases
# Out:
#             Bernalillo  McKinley
# date
# 2020-03-27         0.0       0.0
# 2020-03-28         0.0       0.0
# 2020-03-29         0.0       0.0
# 2020-03-30         0.0       0.0
# 2020-03-31         0.0       0.0
# 2020-04-01         0.0       0.0
# 2020-04-02        16.0       3.0
# 2020-04-03        17.0       4.0
# 2020-04-04        19.0       4.0
# 2020-04-05        21.0       5.0
# 2020-04-06        21.0       5.0
# 2020-04-07        25.0       6.0
# 2020-04-08        25.0       7.0
# 2020-04-09        29.0       9.0
# 2020-04-10        29.0      12.0
# 2020-04-11        28.0      15.0
# 2020-04-12        28.0      15.0
# 2020-04-13        28.0      21.0
# 2020-04-14        23.0      21.0
# 2020-04-15        22.0      25.0
# 2020-04-16        18.0      26.0
# 2020-04-17        16.0      29.0
# 2020-04-18        16.0      31.0
# 2020-04-19        15.0      31.0
# 2020-04-20        16.0      32.0
# 2020-04-21        18.0      37.0
# 2020-04-22        18.0      40.0
# 2020-04-23        20.0      44.0
# 2020-04-24        20.0      46.0
# 2020-04-25        21.0      51.0
# 2020-04-26        22.0      51.0
# 2020-04-27        19.0      52.0
# 2020-04-28        23.0      52.0
# 2020-04-29        25.0      62.0
# 2020-04-30        27.0      65.0
# 2020-05-01        26.0      61.0
# 2020-05-02        31.0      59.0
# 2020-05-03        34.0      61.0
# 2020-05-04        36.0      65.0

# %%
sns.set(style="darkgrid")
df.plot(title='Rolling 7 day average by NM County',figsize=(18,12))
